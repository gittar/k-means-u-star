# %% [markdown]
# # k-means-u and k-means-u* - empirical results
# systematic experiments with different data sets and ranges of $k$
# ## Attention: the simulation runs over larger $k$-ranges can take hours ....

# %%
#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import matplotlib
import bottleneck as bn
import copy
import math
import random
from bfdataset import dataset
from bfutil import finish, whoami, dplot, dplot1
from sklearn.preprocessing import StandardScaler
from kmeansu import kmeansU

# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## set fontsize for plots

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 20}

matplotlib.rc('font', **font)

# %% [markdown]
# # Input Data Sets

# %% [markdown]
# ## 2D grid data (data set A)

# %%
def getAData():
    D = dataset.grid(so=6,si=6,grid1=1,grid2=1)
    print(D.n)
    return D.getData()
#np.savetxt('data/Adata.txt', getAData(), delimiter=' ')
fig=dplot(getAData(),ticks=False,size=10,ms=4.5)
#fig.savefig("img/paperdata.png",bbox_inches='tight', dpi=300)
# Out:
# 1296

# %% [markdown]
# ## 2D data without clusters (data set B)

# %%
def getflatData():
    D = dataset.grid(so=1,si=36,grid1=1,grid2=1)
    
    print(D.n)
    return D.getData()
#np.savetxt('data/flatdata.txt', getFlatData(), delimiter=' ')
fig=dplot(getFlatData(),ticks=False,size=10,ms=4.5)
#fig.savefig("img/flatdata.png",bbox_inches='tight', dpi=300)
# Out:
# 1296

# %% [markdown]
# # 5D gaussian data

# %%
def fig_gaussiandata():
    D=dataset.gaussmixXD(n=2000,d=5,g=50,sig=0.0001)
    a=D.getData()
    fig=dplot(a,ticks=False,size=20)
    return fig, a
def read5DgaussianData():
    newdata = pd.read_csv("data/5Dgaussiandata.txt",sep='\s+', engine='python', header=None)
    return newdata
#read5DgaussianData()
figg, a5 = fig_gaussiandata()
#np.savetxt('data/5Dgaussiandata.txt', a5, delimiter=' ')
#figg.savefig("img/gaussian5D",bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Cloud Data
# https://archive.ics.uci.edu/ml/datasets/Cloud
# * n = 1024
# * d = 10

# %%
def readCloudData():
    newdata = pd.read_csv("data/cloud1.txt",sep='\s+', engine='python', header=None)
    sdata= StandardScaler().fit_transform(newdata)
    #print(newdata.describe())
    return sdata
fig = dplot(readCloudData(),ticks=False);
#fig.savefig("img/clouddata_low.png",bbox_inches='tight', dpi=100)

# %% [markdown]
# ## Propulsion Data
# https://archive.ics.uci.edu/ml/datasets/Condition+Based+Maintenance+of+Naval+Propulsion+Plants#
# * n=11934
# * d=16

# %%
def readPropulsionData():
    newdata = pd.read_csv("data/propulsiondata.txt",sep='\s+', engine='python', header=None)
    sdata= StandardScaler().fit_transform(newdata)
    #print(type(sdata))
    return sdata[:,:-2] # last two columns are steering parameters which are set instead of measured
fig=dplot(readPropulsionData(),ticks=False)
#fig.savefig("img/propulsiondata_low.png",bbox_inches='tight', dpi=100)

# %% [markdown]
# ## Main Simulation Loop
# perform a number of simulation for different values of k
#
# * X: data set
# * sizes: k-values to simulate
# * runsPerModel: How often to run with one k-value and one model
# * n_init: Repeat-Parameter for k-means++
# * table: Print out table?
# * maxRetry: parameter or k-means-u*
# ### Returns: dictionary of pandas dataFrames, one for each $k$-value

# %%
import time
from collections import Counter
def simu(X,sizes, runsPerModel, n_init=10, table=True,maxRetry=2):
    #print("simu(): X=",X)
    #phase0: initialization and normal k-means
    #phase1: improvement with k-means-u
    n0={} # no of Lloyd iterations k-means
    nz={} # no of Lloyd iterations k-means-u
    n1={} # no of Lloyd iterations k-means-u*
    nu={} # no of k-means-u(*) jumps
    e0={} # k-means error
    e1={} # k-means-u error
    e2={} # k-means-u* error
    t0={} # k-means time
    t1={} # k-means-u(*) time
    td={} # %delta time of k-means-u
    C0={} # k-means codebook
    C1={} # k-means-u codebook
    imp = {} # improvement obtained through k-means-u
    impr = {} # improvement obtained through k-means-u*
    nimp = {} # no of improvements
    
    d={} # dict of dataframes, contains statistics of all runs for a value of k
    e={} # contains statistics for all values of k
    # create a pandas dataFrame for each size
    for s in sizes:
        d[str(s)]=pd.DataFrame()
    # k-values
    for k in sizes:
        # seeding methods
        for init,shrt in [("k-means++","km++"),("random","rnd")][:1]:
            #print(init, end=': ')
            n0[init]=[] 
            nz[init]=[] 
            n1[init]=[] 
            nu[init]=[] 
            e0[init]=[] 
            e1[init]=[] 
            e2[init]=[] 
            t0[init]=[] 
            t1[init]=[] 
            td[init]=[] 
            C0[init]=[] 
            C1[init]=[] 
            imp[init]=[]  
            impr[init]=[] 
            nimp[init]=[] 
            for j in range(runsPerModel):

                T0 = time.time()
                kmeans = KMeans(n_clusters=k, init=init, n_init=n_init) # initial run with kmeans++, only one run 
                kmeans.fit(X) # actually compute k-means clustering
                T1= time.time()
                #print(T0,T1,T1-T0)
                Corig = copy.deepcopy(kmeans.cluster_centers_) # remember the k-means result
                C0[init].append(copy.deepcopy(kmeans.cluster_centers_)) # store k-means result
                # initial error from kmeans++
                err0 = 0+kmeans.inertia_
                # estimated number of Lloyd iterations used by k-means++:
                # (iterations of best run) * n_init
                n0[init].append(kmeans.n_iter_*n_init)

                kmeans = kmeansU(X,kmeans,maxRetry=maxRetry,loud=0) # kmeansU
                Cfinal=copy.deepcopy(kmeans.cluster_centers_) # remember the k-means result
                err1 = kmeans.noRetryErr
                err2 = kmeans.inertia_
                #print("err1 {} err2 {}\n".format(err1,err2))
                #print(dir(kmeans))
                #print ("err0:",err0,"err1:", err1, "Impro" if err1<err0 else "no impro")
                nz[init].append(kmeans.n_iter_u0) # Loyd iterations used by k-means-U
                n1[init].append(kmeans.n_iter_un) # Loyd iterations used by k-means-U*
                nu[init].append(kmeans.uruns) # number of non-local jumps

                T2=time.time()
                C1[init].append(copy.deepcopy(kmeans.cluster_centers_)) # store k-means++ result
                if (err2 < err1):
                    # additional improvement by k-means-u*
                    print("*", end='')
                    nimp[init].append(1)
                elif (err1 < err0):
                    # improvement by k-means-u
                    print("+", end='')
                    nimp[init].append(1)
                else:
                    # no improvement
                    print("-", end='')
                    nimp[init].append(0)

                t0[init].append(T1-T0) # time for k-means
                t1[init].append(T2-T1) # time for k-means-u (unoptimized)
                if (T1-T0 > 0):
                    td[init].append(((T2-T0)/(T1-T0)-1.0)) # relative addition of time due to k-means-u
                else:
                    td[init].append(0)

                e0[init].append(err0)  # k-means error
                e1[init].append(err1)  # k-means-u error
                e2[init].append(err2)  # k-means-u* error
                imp[init].append(1.-err1/err0) # improvement obtained through k-means-u
                impr[init].append(1.-err2/err0) # improvement obtained through k-means-u*
            d[str(k)]["n0["+shrt+"]"]=pd.Series(n0[init])
            d[str(k)]["nz["+shrt+"]"]=pd.Series(nz[init])
            d[str(k)]["n1["+shrt+"]"]=pd.Series(n1[init])
            d[str(k)]["nu["+shrt+"]"]=pd.Series(nu[init])
            d[str(k)]["e0["+shrt+"]"]=pd.Series(e0[init])
            d[str(k)]["e1["+shrt+"]"]=pd.Series(e1[init])
            d[str(k)]["e2["+shrt+"]"]=pd.Series(e2[init])
            d[str(k)]["t0["+shrt+"]"]=pd.Series(t0[init])
            d[str(k)]["t1["+shrt+"]"]=pd.Series(t1[init])
            d[str(k)]["td["+shrt+"]"]=pd.Series(td[init])
            d[str(k)]["imp["+shrt+"]"]=pd.Series(imp[init])
            d[str(k)]["impr["+shrt+"]"]=pd.Series(impr[init])
            d[str(k)]["nimp["+shrt+"]"]=pd.Series(nimp[init])
        print("  runsPerModel = ",runsPerModel, "noOfCenters:",k)
        # get important values from the descriobe() result
        ee = np.round(d[str(k)].describe().loc[["mean","std","min","max"]], decimals=4)
        e[k]=ee # store evaluation matrix for current k
        if table:
            from IPython.core.display import display, HTML
            output = ee.filter(regex=(".*km.*")).to_html(formatters={
                'nimp[km++]': '{:,.2%}'.format,
                'nimp[rnd]': '{:,.2%}'.format,
                'imp[km++]': '{:,.2%}'.format,
                'imp[rnd]': '{:,.2%}'.format,
                'td[km++]': '{:,.2%}'.format,
                'td[rnd]': '{:,.2%}'.format,
            })
            display(HTML(output))
        if False:
            output = ee.filter(regex=(".*rnd.*")).to_html(formatters={
                'nimp[km++]': '{:,.2%}'.format,
                'nimp[rnd]': '{:,.2%}'.format,
                'imp[km++]': '{:,.2%}'.format,
                'imp[rnd]': '{:,.2%}'.format,
                'td[km++]': '{:,.2%}'.format,
                'td[rnd]': '{:,.2%}'.format,
            })
            display(HTML(output))
    #print(e)
    return e

# %%
print(res1[6])
# Out:
#       n0[km++]  nz[km++]  n1[km++]  nu[km++]  e0[km++]  e1[km++]  e2[km++]  \
# mean   56.0000    7.3000   27.0000       3.0   34.4583   34.4583   34.4583
# std    20.1108    2.3118    9.7753       0.0    0.0000    0.0000    0.0000
# min    30.0000    3.0000   14.0000       3.0   34.4583   34.4583   34.4583
# max   100.0000    9.0000   44.0000       3.0   34.4583   34.4583   34.4583
#
#       t0[km++]  t1[km++]  td[km++]  imp[km++]  impr[km++]  nimp[km++]
# mean    0.0493    0.1661    3.3884        0.0         0.0         0.0
# std     0.0039    0.0055    0.3110        0.0         0.0         0.0
# min     0.0444    0.1571    2.7622        0.0         0.0         0.0
# max     0.0569    0.1732    3.8056        0.0         0.0         0.0

# %% [markdown]
# ## function for grid drawing

# %%
def dogrid(ax)   :
    ax.grid(True)
    ticklines = ax.get_xticklines() + ax.get_yticklines()
    gridlines = ax.get_xgridlines() + ax.get_ygridlines()
    #ticklabels = ax.get_xticklabels() + ax.get_yticklabels()

    for line in ticklines:
        line.set_linewidth(3)

    for line in gridlines:
        line.set_linestyle('-.')

# %% [markdown]
# ## standard 3-part statistics for given dataset

# %%
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter
def myfunc(y, pos=0):
    return '%1.1f%%'%(100*y)

#def statistics(e,size=(20,10),axdim=(2,1),ms=15,tick_spacing_y1=None, ticks_x=None):
def statistics(e,size=(20,11),axdim=(3,1),ms=15,tick_spacing_y1=None, ticks_x=None):
#def statistics(e,size=(20,5),axdim=(1,1),ms=15,tick_spacing_y1=None, ticks_x=None):
    # mak up to 3 plots of relevant statistical information:
    # improvement over k
    # fraction of improved solutions over k
    # computational overhead over k (how exactly measured?)
    kstar=1
    sizes = sorted(e.keys())
    
    # improvement of k-means-u over k-means++
    mean_imp = np.array([e[x].loc["mean","imp[km++]"]  for x in sizes])
    mean_impr = np.array([e[x].loc["mean","impr[km++]"]  for x in sizes])
    #print("mean:impr",mean_impr)
    #print("mean:imp",mean_imp)
    
    max_imp = np.array([e[x].loc["max","imp[km++]"]   for x in sizes])
    max_impr = np.array([e[x].loc["max","impr[km++]"]   for x in sizes])
    min_imp = np.array([e[x].loc["min","imp[km++]"]   for x in sizes])
    min_impr = np.array([e[x].loc["min","impr[km++]"]   for x in sizes])
    std_imp = np.array([e[x].loc["std","imp[km++]"]   for x in sizes])
    #print("mean",mean_imp)
    
    mean_nimp = [e[x].loc["mean","nimp[km++]"] for x in sizes]
    mean_n0  = [e[x].loc["mean","n0[km++]"]   for x in sizes]
    mean_nz  = [e[x].loc["mean","nz[km++]"]   for x in sizes]
    #print("mean:nz",np.array(mean_nz)/np.array(mean_n0))
    mean_n1  = [e[x].loc["mean","n1[km++]"]   for x in sizes]
    #print("mean:n1",np.array(mean_n1)/np.array(mean_n0))
    mean_e0  = [e[x].loc["mean","e0[km++]"]   for x in sizes]
    mean_e1  = [e[x].loc["mean","e1[km++]"]   for x in sizes]
    #print("meann",mean_nimp)

    fig,axs = plt.subplots(*axdim)
    fig.set_size_inches(*size)
    if axdim == (1,1):
        axs=[axs]
    ##
    ## Improvement
    ##
    ax=axs[0]
    #ax.plot(sizes,max_imp,"ro-",label="max improvement")
    #ax.set_ylim([0, 0.15])
    mini = np.min(sizes)
    maxi = np.max(sizes)
    #print(mini," - " , maxi, maxi-mini)
    if kstar:
        off = (maxi-mini)/800.0
        ax.errorbar(np.array(sizes)+off,mean_impr,yerr=[mean_impr-min_impr,
                    max_impr-mean_impr],capsize=4,fmt="ro-",linewidth=3,elinewidth=1,label='k-means-u*')
        ax.errorbar(np.array(sizes)-off,mean_imp,yerr=[mean_imp-min_imp,
                    max_imp-mean_imp],capsize=4,fmt="o-",linewidth=3,elinewidth=1,label='k-means-u')
    else:
        ax.errorbar(np.array(sizes),mean_imp,yerr=[mean_imp-min_imp,max_imp-mean_imp],
                    capsize=4,fmt="o-",linewidth=3,elinewidth=1)
        
    #ax.plot(np.array(sizes),mean_impr,"ro-",zorder=10)
    if kstar:
        #if dataname 
        ax.set_title("SSE reduction of k-means-u/k-means-u* over k-means++")
        #ax.set_title("SSE reduction of k-means-u and k-means-u* over k-means++")
    else:
        ax.set_title("SSE reduction of k-means-u over k-means++")
    #tick_spacing = 0.025
    if tick_spacing_y1 is not None:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing_y1))
    if ticks_x is not None:
        ax.xaxis.set_ticks(ticks_x)
    if 1:
        dogrid(ax)
        #ax.legend()
        handles, labels = ax.get_legend_handles_labels()
        ax.legend(handles, labels)
        ax.set_xlabel('$k$')
        ax.set_ylabel('SSE reduction')
        
        ttl = ax.title
        ttl.set_position([.5, 1.03])

    # manipulate axis to show percent
    #vals = ax.get_yticks()
    #print("valla",vals)
    
    #fmt = '%.3f%%' # Format you want the ticks, e.g. '40%'
    #yticks = ticker.FormatStrFormatter(fmt)
    #ax.yaxis.set_major_formatter(yticks)
    ax.yaxis.set_major_formatter(FuncFormatter(myfunc))

    #ax.set_yticklabels(['{:3.1f}%'.format(x*100) for x in vals])
    #ax.set_ylim(bottom=0)

    if axdim == (3,1):
        ##
        ## Fraction Improvement
        ##
        ax=axs[2]
        ax.set_ylim([0, 1.1])
        ax.plot(sizes,mean_nimp,"r.-",ms=ms)
        ax.set_title("fraction of k-means++ solutions improved by k-means-u*")
        dogrid(ax)

        # manipulate axis to show percent
        vals = ax.get_yticks()
        ax.set_yticklabels(['{:3.1f}%'.format(x*100) for x in vals])
        #ax.set_ylim(0,1)
        ttl = ax.title
        ttl.set_position([.5, 1.03])
        
        ##
        ## Computation
        ##
        ax=axs[1]
        ax.plot(sizes,np.array(mean_n1)/np.array(mean_n0),"r.-",ms=ms,label='k-means-u*')
        #print(np.array(mean_n1)/np.array(mean_n0))
        ax.plot(sizes,np.array(mean_nz)/np.array(mean_n0),".-",ms=ms,label='k-means-u')
        #print(np.array(mean_nz)/np.array(mean_n0))
        ax.set_title("additional Lloyd iterations needed by kmeans-u/k-means-u* (relative to k-means++)")
        dogrid(ax)
        #if tick_spacing_y1 is not None:
        #    ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing_y1))
        if ticks_x is not None:
            ax.xaxis.set_ticks(ticks_x)
        ax.set_xlabel('$k$')
        ax.set_ylabel('add. Lloyd iterations %')
        if 1:
            # legend
            handles, labels = ax.get_legend_handles_labels()
            ax.legend(handles, labels)
            # manipulate axis to show percent
            vals = ax.get_yticks()
            ax.set_yticklabels(['{:3.1f}%'.format(x*100) for x in vals])
            #ax.set_ylim(bottom=0) # do not use this !!!!!
            #ax.set_xlabel('$k$')
        if 0:
            if ticks_x is not None:
                ax.xaxis.set_ticks(ticks_x)
            ttl = ax.title
            ttl.set_position([.5, 1.03])

    if False:
        ax=axs[3]
        ax.semilogy(sizes,mean_e0,"o-")
        ax.semilogy(sizes,mean_e1,"o-")
        ax.set_title("error")
    plt.subplots_adjust(wspace=4.03, hspace=0.5)

    return fig

# %% [markdown]
# ## parameters to steer the mass simulations

# %%
table=False
full=0 # if True or 1, use a large $k$-range
write=0 # write out figures to disk?
suffix="ZZZ" # added to generated png files
runsPerModel=10 # for each calue of $k$ that manu runs are performed
persist=0 # write out simulation results to file for later reuse

# %% [markdown]
# ## data set $A$ simulation

# %%
if full:
    s = list(range(6*6*0+6,6*6*12+6*6,6))
else:
    s = list([6,12,18, 24,40,80])
print (s)
X = getAData()
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 126, 132, 138, 144, 150, 156, 162, 168, 174, 180, 186, 192, 198, 204, 210, 216, 222, 228, 234, 240, 246, 252, 258, 264, 270, 276, 282, 288, 294, 300, 306, 312, 318, 324, 330, 336, 342, 348, 354, 360, 366, 372, 378, 384, 390, 396, 402, 408, 414, 420, 426, 432, 438, 444, 450, 456, 462]

# %%
res1=simu(X,sizes=s,runsPerModel=runsPerModel, table=table,maxRetry=2)
# Out:
# ----------  runsPerModel =  10 noOfCenters: 6
# ---+------  runsPerModel =  10 noOfCenters: 12
# ---*----+*  runsPerModel =  10 noOfCenters: 18
# +-+*----+-  runsPerModel =  10 noOfCenters: 24
# -+++-+++++  runsPerModel =  10 noOfCenters: 30
# ----------  runsPerModel =  10 noOfCenters: 36
# ----------  runsPerModel =  10 noOfCenters: 42
# ----------  runsPerModel =  10 noOfCenters: 48
# --++-++---  runsPerModel =  10 noOfCenters: 54
# -++-++++++  runsPerModel =  10 noOfCenters: 60
# ++*+++++++  runsPerModel =  10 noOfCenters: 66
# ++++++++++  runsPerModel =  10 noOfCenters: 72
# *++*+*+*++  runsPerModel =  10 noOfCenters: 78
# ++*+***+**  runsPerModel =  10 noOfCenters: 84
# ***++++*+*  runsPerModel =  10 noOfCenters: 90
# **+*******  runsPerModel =  10 noOfCenters: 96
# ********+*  runsPerModel =  10 noOfCenters: 102
# ++++++++++  runsPerModel =  10 noOfCenters: 108
# +++++*+*+*  runsPerModel =  10 noOfCenters: 114
# +++*+++++*  runsPerModel =  10 noOfCenters: 120
# ++++*++*+*  runsPerModel =  10 noOfCenters: 126
# +++++*++*+  runsPerModel =  10 noOfCenters: 132
# +++++++*++  runsPerModel =  10 noOfCenters: 138
# +*++++*++*  runsPerModel =  10 noOfCenters: 144
# ++***+++++  runsPerModel =  10 noOfCenters: 150
# ++*+++++++  runsPerModel =  10 noOfCenters: 156
# *+++++++++  runsPerModel =  10 noOfCenters: 162
# +++++++++*  runsPerModel =  10 noOfCenters: 168
# ++++++++++  runsPerModel =  10 noOfCenters: 174
# ++++++++++  runsPerModel =  10 noOfCenters: 180
# ++++++*+++  runsPerModel =  10 noOfCenters: 186
# ++*++*++++  runsPerModel =  10 noOfCenters: 192
# ++++++++++  runsPerModel =  10 noOfCenters: 198
# +++*++++*+  runsPerModel =  10 noOfCenters: 204
# ++++++*+++  runsPerModel =  10 noOfCenters: 210
# +++*+++*++  runsPerModel =  10 noOfCenters: 216
# +*++++*+++  runsPerModel =  10 noOfCenters: 222
# ++++++++++  runsPerModel =  10 noOfCenters: 228
# ++++++++**  runsPerModel =  10 noOfCenters: 234
# **+++++**+  runsPerModel =  10 noOfCenters: 240
# ++++++*++*  runsPerModel =  10 noOfCenters: 246
# +*+*++*++*  runsPerModel =  10 noOfCenters: 252
# +***+**+**  runsPerModel =  10 noOfCenters: 258
# *+***+**+*  runsPerModel =  10 noOfCenters: 264
# *****+****  runsPerModel =  10 noOfCenters: 270
# *++*+****+  runsPerModel =  10 noOfCenters: 276
# +******+*+  runsPerModel =  10 noOfCenters: 282
# **+*+****+  runsPerModel =  10 noOfCenters: 288
# ****++*++*  runsPerModel =  10 noOfCenters: 294
# ++*++*++++  runsPerModel =  10 noOfCenters: 300
# +****+*+*+  runsPerModel =  10 noOfCenters: 306
# *++*******  runsPerModel =  10 noOfCenters: 312
# ***+******  runsPerModel =  10 noOfCenters: 318
# *+*****+**  runsPerModel =  10 noOfCenters: 324
# **********  runsPerModel =  10 noOfCenters: 330
# *****+***+  runsPerModel =  10 noOfCenters: 336
# ********+*  runsPerModel =  10 noOfCenters: 342
# +****+***+  runsPerModel =  10 noOfCenters: 348
# ******++**  runsPerModel =  10 noOfCenters: 354
# ****+*****  runsPerModel =  10 noOfCenters: 360
# **********  runsPerModel =  10 noOfCenters: 366
# ******+++*  runsPerModel =  10 noOfCenters: 372
# ******+***  runsPerModel =  10 noOfCenters: 378
# **+*******  runsPerModel =  10 noOfCenters: 384
# ****+*++*+  runsPerModel =  10 noOfCenters: 390
# *******+*+  runsPerModel =  10 noOfCenters: 396
# ***+******  runsPerModel =  10 noOfCenters: 402
# *++*******  runsPerModel =  10 noOfCenters: 408
# +++*+**++*  runsPerModel =  10 noOfCenters: 414
# *+*+******  runsPerModel =  10 noOfCenters: 420
# +**+++**+*  runsPerModel =  10 noOfCenters: 426
# +***+**++*  runsPerModel =  10 noOfCenters: 432
# +******+++  runsPerModel =  10 noOfCenters: 438
# **+**+*+**  runsPerModel =  10 noOfCenters: 444
# ++**+***++  runsPerModel =  10 noOfCenters: 450
# *+**+++++*  runsPerModel =  10 noOfCenters: 456
# +*++*++**+  runsPerModel =  10 noOfCenters: 462

# %%
def perma(ob,name,code):
    f = name+"_"+code+".pickle"
    with open(f, 'wb') as handle:
        pickle.dump(ob, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print ("pickled: ",f)
def unperma(f):
    with open(f, 'rb') as handle:
        b = pickle.load(handle)
        return(b)

# %%
code="0624"

# %%
if persist:
    perma(res1,"res1",code)

# %%
ticks_x=np.concatenate((np.array([0]),np.arange(36, 13*36, 36),np.array([462])))
print(ticks_x)
fig1 = statistics(res1, tick_spacing_y1=0.02, ticks_x=ticks_x)#,size=(20,16))
#fig1 = statistics(res1, tick_spacing_y1=0.02)#,size=(20,16))

#fig = statistics(res1)
if write:
    fig1.savefig("img/gaussian2Dstat"+suffix+".png",bbox_inches='tight', dpi=300)
# Out:
# [  0  36  72 108 144 180 216 252 288 324 360 396 432 462]

# %% [markdown]
# ## FlatData simulation

# %%
if full:
    s = list(range(6*6*0+6,6*6*12+6*6,6))
else:
    s = list([6,12,18, 24,40,80])
print (s)
X = getFlatData()
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96, 102, 108, 114, 120, 126, 132, 138, 144, 150, 156, 162, 168, 174, 180, 186, 192, 198, 204, 210, 216, 222, 228, 234, 240, 246, 252, 258, 264, 270, 276, 282, 288, 294, 300, 306, 312, 318, 324, 330, 336, 342, 348, 354, 360, 366, 372, 378, 384, 390, 396, 402, 408, 414, 420, 426, 432, 438, 444, 450, 456, 462]
# 1296

# %%
res1a=simu(X,sizes=s,runsPerModel=runsPerModel, table=table,maxRetry=2)
# Out:
# ----------  runsPerModel =  10 noOfCenters: 6
# -+-*--*-*-  runsPerModel =  10 noOfCenters: 12
# ----*--***  runsPerModel =  10 noOfCenters: 18
# +++++--*--  runsPerModel =  10 noOfCenters: 24
# *-+--+***-  runsPerModel =  10 noOfCenters: 30
# -+--*-+++*  runsPerModel =  10 noOfCenters: 36
# +++-*+*-++  runsPerModel =  10 noOfCenters: 42
# +*+++**+++  runsPerModel =  10 noOfCenters: 48
# ++*+*++-++  runsPerModel =  10 noOfCenters: 54
# +*-**+***-  runsPerModel =  10 noOfCenters: 60
# ++*++*****  runsPerModel =  10 noOfCenters: 66
# **+*+*+++*  runsPerModel =  10 noOfCenters: 72
# *+**+++***  runsPerModel =  10 noOfCenters: 78
# ++++**+**+  runsPerModel =  10 noOfCenters: 84
# *+**+*+++*  runsPerModel =  10 noOfCenters: 90
# +*+*+--**+  runsPerModel =  10 noOfCenters: 96
# *-++*++*++  runsPerModel =  10 noOfCenters: 102
# *++*+*++++  runsPerModel =  10 noOfCenters: 108
# +****+****  runsPerModel =  10 noOfCenters: 114
# **+++*+***  runsPerModel =  10 noOfCenters: 120
# **++**++++  runsPerModel =  10 noOfCenters: 126
# +***+****+  runsPerModel =  10 noOfCenters: 132
# *++++*++**  runsPerModel =  10 noOfCenters: 138
# *++***++*+  runsPerModel =  10 noOfCenters: 144
# ***+*+*+**  runsPerModel =  10 noOfCenters: 150
# *+**+***+*  runsPerModel =  10 noOfCenters: 156
# *+**++****  runsPerModel =  10 noOfCenters: 162
# **+*++*+**  runsPerModel =  10 noOfCenters: 168
# +*+++*****  runsPerModel =  10 noOfCenters: 174
# **+*******  runsPerModel =  10 noOfCenters: 180
# ***+****+*  runsPerModel =  10 noOfCenters: 186
# *+******++  runsPerModel =  10 noOfCenters: 192
# +**++*++**  runsPerModel =  10 noOfCenters: 198
# *+++*+++++  runsPerModel =  10 noOfCenters: 204
# **+++****+  runsPerModel =  10 noOfCenters: 210
# *+++++*++*  runsPerModel =  10 noOfCenters: 216
# +*++*++*++  runsPerModel =  10 noOfCenters: 222
# *++*++++**  runsPerModel =  10 noOfCenters: 228
# ++++**+++*  runsPerModel =  10 noOfCenters: 234
# *+**++*+++  runsPerModel =  10 noOfCenters: 240
# *+*+****+*  runsPerModel =  10 noOfCenters: 246
# **+******+  runsPerModel =  10 noOfCenters: 252
# ++***++***  runsPerModel =  10 noOfCenters: 258
# **+**+++**  runsPerModel =  10 noOfCenters: 264
# ++*+****+*  runsPerModel =  10 noOfCenters: 270
# *+*++*++**  runsPerModel =  10 noOfCenters: 276
# ***+**+++*  runsPerModel =  10 noOfCenters: 282
# ***+++****  runsPerModel =  10 noOfCenters: 288
# +****+****  runsPerModel =  10 noOfCenters: 294
# *****++*+*  runsPerModel =  10 noOfCenters: 300
# *+**+****+  runsPerModel =  10 noOfCenters: 306
# *******+*+  runsPerModel =  10 noOfCenters: 312
# ****+*+***  runsPerModel =  10 noOfCenters: 318
# **********  runsPerModel =  10 noOfCenters: 324
# ++********  runsPerModel =  10 noOfCenters: 330
# ********+*  runsPerModel =  10 noOfCenters: 336
# *********+  runsPerModel =  10 noOfCenters: 342
# **+*******  runsPerModel =  10 noOfCenters: 348
# ***+**+++*  runsPerModel =  10 noOfCenters: 354
# *+***+****  runsPerModel =  10 noOfCenters: 360
# *********+  runsPerModel =  10 noOfCenters: 366
# **********  runsPerModel =  10 noOfCenters: 372
# ****+*****  runsPerModel =  10 noOfCenters: 378
# ******+***  runsPerModel =  10 noOfCenters: 384
# ***++*+***  runsPerModel =  10 noOfCenters: 390
# ****++****  runsPerModel =  10 noOfCenters: 396
# ***+******  runsPerModel =  10 noOfCenters: 402
# **********  runsPerModel =  10 noOfCenters: 408
# ***++**+**  runsPerModel =  10 noOfCenters: 414
# *****+****  runsPerModel =  10 noOfCenters: 420
# ****+*****  runsPerModel =  10 noOfCenters: 426
# *********+  runsPerModel =  10 noOfCenters: 432
# ***+******  runsPerModel =  10 noOfCenters: 438
# **********  runsPerModel =  10 noOfCenters: 444
# ********+*  runsPerModel =  10 noOfCenters: 450
# +*********  runsPerModel =  10 noOfCenters: 456
# **+*******  runsPerModel =  10 noOfCenters: 462

# %%
if persist:
    perma(res1a,"res1a",code)

# %%
ticks_x=np.concatenate((np.array([0]),np.arange(36, 13*36, 36),np.array([462])))
print(ticks_x)
fig1a = statistics(res1a, tick_spacing_y1=0.02, ticks_x=ticks_x)#,size=(20,16))
#fig1 = statistics(res1, tick_spacing_y1=0.02)#,size=(20,16))

#fig = statistics(res1)
if write:
    fig1a.savefig("img/flat2Dstat"+suffix+".png",bbox_inches='tight', dpi=300)
# Out:
# [  0  36  72 108 144 180 216 252 288 324 360 396 432 462]

# %%
#print(res1)

# %% [markdown]
# ## 5D Gaussian simulation

# %%
D=dataset.gaussmixXD(n=2000,d=5,g=50,sig=0.00001)
X=D.getData()
if full:
    s = list(range(10,500,10))+list(range(500,2020,20))
else:
    s = list(range(10,50,10))
#plt.plot(X[:,0],X[:,1],".",ms=1)
#plt.show()

    
res2=simu(X,sizes=s,runsPerModel=runsPerModel, table=table)
# Out:
# +*-+*-+--+  runsPerModel =  10 noOfCenters: 10
# ++++--*+++  runsPerModel =  10 noOfCenters: 20
# -++*++*-*+  runsPerModel =  10 noOfCenters: 30
# ----------  runsPerModel =  10 noOfCenters: 40
# ----------  runsPerModel =  10 noOfCenters: 50
# +**+++****  runsPerModel =  10 noOfCenters: 60
# ***+*+**+*  runsPerModel =  10 noOfCenters: 70
# +*+*++****  runsPerModel =  10 noOfCenters: 80
# **+*******  runsPerModel =  10 noOfCenters: 90
# *****+*+*+  runsPerModel =  10 noOfCenters: 100
# *+*+*+**+*  runsPerModel =  10 noOfCenters: 110
# ***++*****  runsPerModel =  10 noOfCenters: 120
# *+*+**+*+*  runsPerModel =  10 noOfCenters: 130
# *+****+***  runsPerModel =  10 noOfCenters: 140
# ***+******  runsPerModel =  10 noOfCenters: 150
# *+***+***+  runsPerModel =  10 noOfCenters: 160
# **+****+**  runsPerModel =  10 noOfCenters: 170
# +**+++*+**  runsPerModel =  10 noOfCenters: 180
# *+********  runsPerModel =  10 noOfCenters: 190
# +***+*****  runsPerModel =  10 noOfCenters: 200
# **+***+***  runsPerModel =  10 noOfCenters: 210
# *****+****  runsPerModel =  10 noOfCenters: 220
# +***+*****  runsPerModel =  10 noOfCenters: 230
# ****+**+*+  runsPerModel =  10 noOfCenters: 240
# *++*+*****  runsPerModel =  10 noOfCenters: 250
# **********  runsPerModel =  10 noOfCenters: 260
# ***+******  runsPerModel =  10 noOfCenters: 270
# +****+****  runsPerModel =  10 noOfCenters: 280
# ***+***+**  runsPerModel =  10 noOfCenters: 290
# **********  runsPerModel =  10 noOfCenters: 300
# ***+**+***  runsPerModel =  10 noOfCenters: 310
# ****+**++*  runsPerModel =  10 noOfCenters: 320
# *****++**+  runsPerModel =  10 noOfCenters: 330
# ******+***  runsPerModel =  10 noOfCenters: 340
# ****+*****  runsPerModel =  10 noOfCenters: 350
# **********  runsPerModel =  10 noOfCenters: 360
# ******+***  runsPerModel =  10 noOfCenters: 370
# *+*****+**  runsPerModel =  10 noOfCenters: 380
# +*****++**  runsPerModel =  10 noOfCenters: 390
# *+**+*****  runsPerModel =  10 noOfCenters: 400
# ********+*  runsPerModel =  10 noOfCenters: 410
# *+**+*****  runsPerModel =  10 noOfCenters: 420
# ********+*  runsPerModel =  10 noOfCenters: 430
# +**++***+*  runsPerModel =  10 noOfCenters: 440
# **+****++*  runsPerModel =  10 noOfCenters: 450
# **********  runsPerModel =  10 noOfCenters: 460
# *****+***+  runsPerModel =  10 noOfCenters: 470
# **********  runsPerModel =  10 noOfCenters: 480
# ********+*  runsPerModel =  10 noOfCenters: 490
# ********+*  runsPerModel =  10 noOfCenters: 500
# **+******+  runsPerModel =  10 noOfCenters: 520
# **********  runsPerModel =  10 noOfCenters: 540
# **********  runsPerModel =  10 noOfCenters: 560
# *******+**  runsPerModel =  10 noOfCenters: 580
# **********  runsPerModel =  10 noOfCenters: 600
# **++******  runsPerModel =  10 noOfCenters: 620
# +****+****  runsPerModel =  10 noOfCenters: 640
# *********+  runsPerModel =  10 noOfCenters: 660
# ***++*+*+*  runsPerModel =  10 noOfCenters: 680
# ********+*  runsPerModel =  10 noOfCenters: 700
# ******+***  runsPerModel =  10 noOfCenters: 720
# **********  runsPerModel =  10 noOfCenters: 740
# *******+**  runsPerModel =  10 noOfCenters: 760
# ***+*****+  runsPerModel =  10 noOfCenters: 780
# *******+*+  runsPerModel =  10 noOfCenters: 800
# +*********  runsPerModel =  10 noOfCenters: 820
# **********  runsPerModel =  10 noOfCenters: 840
# **********  runsPerModel =  10 noOfCenters: 860
# *********+  runsPerModel =  10 noOfCenters: 880
# *********+  runsPerModel =  10 noOfCenters: 900
# **********  runsPerModel =  10 noOfCenters: 920
# **********  runsPerModel =  10 noOfCenters: 940
# +*****+**+  runsPerModel =  10 noOfCenters: 960
# *******+**  runsPerModel =  10 noOfCenters: 980
# *****+****  runsPerModel =  10 noOfCenters: 1000
# **********  runsPerModel =  10 noOfCenters: 1020
# *+********  runsPerModel =  10 noOfCenters: 1040
# **********  runsPerModel =  10 noOfCenters: 1060
# **********  runsPerModel =  10 noOfCenters: 1080
# **********  runsPerModel =  10 noOfCenters: 1100
# **********  runsPerModel =  10 noOfCenters: 1120
# ********+*  runsPerModel =  10 noOfCenters: 1140
# ********+*  runsPerModel =  10 noOfCenters: 1160
# ******++**  runsPerModel =  10 noOfCenters: 1180
# ***+**+***  runsPerModel =  10 noOfCenters: 1200
# ********+*  runsPerModel =  10 noOfCenters: 1220
# **********  runsPerModel =  10 noOfCenters: 1240
# ********+*  runsPerModel =  10 noOfCenters: 1260
# **********  runsPerModel =  10 noOfCenters: 1280
# ********+*  runsPerModel =  10 noOfCenters: 1300
# **********  runsPerModel =  10 noOfCenters: 1320
# **********  runsPerModel =  10 noOfCenters: 1340
# ***+******  runsPerModel =  10 noOfCenters: 1360
# *********+  runsPerModel =  10 noOfCenters: 1380
# **********  runsPerModel =  10 noOfCenters: 1400
# **+*******  runsPerModel =  10 noOfCenters: 1420
# **********  runsPerModel =  10 noOfCenters: 1440
# ****+*****  runsPerModel =  10 noOfCenters: 1460
# ****+***+*  runsPerModel =  10 noOfCenters: 1480
# ********+*  runsPerModel =  10 noOfCenters: 1500
# **++*****+  runsPerModel =  10 noOfCenters: 1520
# *********+  runsPerModel =  10 noOfCenters: 1540
# **********  runsPerModel =  10 noOfCenters: 1560
# **********  runsPerModel =  10 noOfCenters: 1580
# **********  runsPerModel =  10 noOfCenters: 1600
# *++*******  runsPerModel =  10 noOfCenters: 1620
# **********  runsPerModel =  10 noOfCenters: 1640
# +*********  runsPerModel =  10 noOfCenters: 1660
# +***++****  runsPerModel =  10 noOfCenters: 1680
# *++*****+*  runsPerModel =  10 noOfCenters: 1700
# ****++****  runsPerModel =  10 noOfCenters: 1720
# **+*******  runsPerModel =  10 noOfCenters: 1740
# *++**+****  runsPerModel =  10 noOfCenters: 1760
# ****+*+*+*  runsPerModel =  10 noOfCenters: 1780
# +*+*+**+++  runsPerModel =  10 noOfCenters: 1800
# **+*****+*  runsPerModel =  10 noOfCenters: 1820
# ***++++*+*  runsPerModel =  10 noOfCenters: 1840
# *+++++*+++  runsPerModel =  10 noOfCenters: 1860
# **+**+***+  runsPerModel =  10 noOfCenters: 1880
# ++*++++*++  runsPerModel =  10 noOfCenters: 1900
# +*+-+-+-**  runsPerModel =  10 noOfCenters: 1920
# +++*++++++  runsPerModel =  10 noOfCenters: 1940
# ++++++++++  runsPerModel =  10 noOfCenters: 1960
# ----+-----  runsPerModel =  10 noOfCenters: 1980
# ----------  runsPerModel =  10 noOfCenters: 2000

# %%
if persist:
    perma(res2,"res2",code)

# %%
fig2 = statistics(res2, tick_spacing_y1=0.01)
if write:
    fig2.savefig("img/gaussian5Dstat"+suffix+".png",bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Cloud Data Simulation

# %%
X = readCloudData()
if full:
    s = list(range(10,1010,20))+[1024]
else:
    s = list(range(10,40,10))
res3=simu(X,sizes=s,runsPerModel=runsPerModel, table=table)
# Out:
# ------*--*  runsPerModel =  10 noOfCenters: 10
# +++*++*++-  runsPerModel =  10 noOfCenters: 30
# *+++++++**  runsPerModel =  10 noOfCenters: 50
# *-+*++*+++  runsPerModel =  10 noOfCenters: 70
# +++*+**+++  runsPerModel =  10 noOfCenters: 90
# +*++++***+  runsPerModel =  10 noOfCenters: 110
# +***++***+  runsPerModel =  10 noOfCenters: 130
# ***++***+*  runsPerModel =  10 noOfCenters: 150
# ******++**  runsPerModel =  10 noOfCenters: 170
# +*********  runsPerModel =  10 noOfCenters: 190
# *++**+****  runsPerModel =  10 noOfCenters: 210
# ********+*  runsPerModel =  10 noOfCenters: 230
# ***+******  runsPerModel =  10 noOfCenters: 250
# *****+****  runsPerModel =  10 noOfCenters: 270
# ++***++***  runsPerModel =  10 noOfCenters: 290
# **********  runsPerModel =  10 noOfCenters: 310
# +********+  runsPerModel =  10 noOfCenters: 330
# *+*+*+*+**  runsPerModel =  10 noOfCenters: 350
# **+******+  runsPerModel =  10 noOfCenters: 370
# **********  runsPerModel =  10 noOfCenters: 390
# *******++*  runsPerModel =  10 noOfCenters: 410
# **++*+*+**  runsPerModel =  10 noOfCenters: 430
# ********+*  runsPerModel =  10 noOfCenters: 450
# **********  runsPerModel =  10 noOfCenters: 470
# **********  runsPerModel =  10 noOfCenters: 490
# *********+  runsPerModel =  10 noOfCenters: 510
# ****++****  runsPerModel =  10 noOfCenters: 530
# **++******  runsPerModel =  10 noOfCenters: 550
# *********+  runsPerModel =  10 noOfCenters: 570
# +***+*****  runsPerModel =  10 noOfCenters: 590
# **+*******  runsPerModel =  10 noOfCenters: 610
# *+*******+  runsPerModel =  10 noOfCenters: 630
# ****++*+*+  runsPerModel =  10 noOfCenters: 650
# +******+**  runsPerModel =  10 noOfCenters: 670
# ********+*  runsPerModel =  10 noOfCenters: 690
# **********  runsPerModel =  10 noOfCenters: 710
# ***++***+*  runsPerModel =  10 noOfCenters: 730
# ****+****+  runsPerModel =  10 noOfCenters: 750
# *+******+*  runsPerModel =  10 noOfCenters: 770
# **+******+  runsPerModel =  10 noOfCenters: 790
# **+*+*****  runsPerModel =  10 noOfCenters: 810
# **+*+**++*  runsPerModel =  10 noOfCenters: 830
# ******+***  runsPerModel =  10 noOfCenters: 850
# *******-+*  runsPerModel =  10 noOfCenters: 870
# ****+*+*+*  runsPerModel =  10 noOfCenters: 890
# *+**+***++  runsPerModel =  10 noOfCenters: 910
# *+*++*+++*  runsPerModel =  10 noOfCenters: 930
# ****+***+*  runsPerModel =  10 noOfCenters: 950
# ++++*+*+*+  runsPerModel =  10 noOfCenters: 970
# *-++-*++*+  runsPerModel =  10 noOfCenters: 990
# ----------  runsPerModel =  10 noOfCenters: 1024

# %%
if persist:
    perma(res3,"res3",code)

# %%
fig3 = statistics(res3, tick_spacing_y1=0.01)
if write:
    fig3.savefig("img/cloudstat"+suffix+".png",bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Propulsion Data Simulation

# %%
if 0:
    table=False
    full=0
    write=0
    suffix="ZZX"
    runsPerModel=5
    persist=0

# %%
X = readPropulsionData()
if full:
    s = list(range(10,500,20))+list(range(500,1040,20))
else:
    s = list(range(200,220,10))
res4=simu(X,sizes=s,runsPerModel=runsPerModel, table=table)
# Out:
# +**++  runsPerModel =  5 noOfCenters: 200
# +*++*  runsPerModel =  5 noOfCenters: 210

# %%
if persist:
    perma(res4,"res4",code)

# %%
#aa = unperma("res4_0623.pickle")
#statistics(aa);

# %%
fig4 = statistics(res4)
#write=1
if write:
    fig4.savefig("img/propulsionstats"+suffix+".png",bbox_inches='tight', dpi=300)
